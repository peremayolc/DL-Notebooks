# %% [markdown]
# <a href="https://colab.research.google.com/github/dkaratzas/DL2022-23/blob/main/Problems%208%20-%20RNNs/P8_RNNs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [![Open In SageMaker Studio Lab](https://studiolab.sagemaker.aws/studiolab.svg)](https://studiolab.sagemaker.aws/import/github/dkaratzas/DL2022-23/blob/main/Problems%208%20-%20RNNs/P8_RNNs.ipynb)

# %% [markdown]
# # Text generation with an RNN
#
# In this notebook we will learn how to generate text with a Recurrent Neural Network.
#
# We will work with a dataset of Shakespeare's writing from Andrej Karpathy's article [The Unreasonable Effectiveness of Recurrent Neural Networks](http://karpathy.github.io/2015/05/21/rnn-effectiveness/).
#
# Given a sequence of characters from this data (for example "Shakespear"), we will train a model to predict the next character in the sequence ("e"). Longer sequences of text can be generated by calling the model repeatedly.

# %% [markdown]
# ### Import the necessary modules

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from torch.utils.data import TensorDataset, DataLoader, Dataset

import matplotlib.pyplot as plt
from collections import Counter
import time
import os
import copy
print("PyTorch Version: ",torch.__version__)
# Out:
# PyTorch Version:  2.2.1+cu121

# %%
#If this cell fails you need to change the runtime of your colab notebook to GPU
# Go to Runtime -> Change Runtime Type and select GPU
assert torch.cuda.is_available(), "GPU is not enabled"

#  use gpu if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cuda

# %% [markdown]
# ### Download the Shakespeare dataset

# %%
! wget https://storage.googleapis.com/download.tensorflow.org/data/shakespeare.txt
# Out:
# --2024-04-29 16:57:10--  https://storage.googleapis.com/download.tensorflow.org/data/shakespeare.txt
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.197.207, 74.125.135.207, 74.125.142.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.197.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1115394 (1.1M) [text/plain]
# Saving to: ‘shakespeare.txt.3’
#
# shakespeare.txt.3   100%[===================>]   1.06M  --.-KB/s    in 0.008s
#
# 2024-04-29 16:57:10 (130 MB/s) - ‘shakespeare.txt.3’ saved [1115394/1115394]

# %% [markdown]
# ###  Create a dataset class
#
# For training we need a dataset of (input, label) pairs. Where input and label are sequences of characters. At each time step the input is the current character and the label is the next character. For example:
#
# ```
# input = ['S', 'h', 'a', 'k', 'e', 's', 'p', 'e', 'a', 'r']
# label = ['h', 'a', 'k', 'e', 's', 'p', 'e', 'a', 'r', 'e']
#  ```
#
# Actually we will vectorize the characters to convert them into numerical values.
#
# ```
# input = [44, 7, 0, 10, 4, 18, 15, 4, 0, 17]
# label = [7, 0, 10, 4, 18, 15, 4, 0, 17, 4]
# ```
#
# where each integer value is a class label, and the number of classes is the number of unique characters in our training data (our vocabulary size).

# %%
Dataset?

# %%
class DatasetFromTextFile(Dataset):
    def __init__(self, filename, sequence_length):
        self.filename = filename
        self.sequence_length = sequence_length

        # The whole sequence of characters in the text file (including characters like the end of line character '\n', punctuation marks, etc.)
        self.chars = self.load_chars()
        # The list of unique characters (our vocabulary)
        self.uniq_chars = self.get_uniq_chars()

        # A dictionary with indices as keys and characters as values
        self.index_to_char = {index: char for index, char in enumerate(self.uniq_chars)}
        # A dictionary with characters as keys and indices as values
        self.char_to_index = {char: index for index, char in enumerate(self.uniq_chars)}

        # The whole sequence of character indexes
        # We want to vectorize our text using one-hot vectors at character level
        # But instead of using the one-hot vector we just keep the index of the 1 value
        self.chars_indices = [self.char_to_index[w] for w in self.chars]

        # Split the sequence into chunks of `sequence_length` characters
        # `x` is the input to the model and `y` is the output of the model
        # `y` is the same seuqence as `x` but one character shifted to the right.
        self.x, self.y = self.get_data()

    def load_chars(self):
        with open(self.filename) as fp:
            text = fp.read()
        print(f'Length of text: {len(text)} characters')
        return text

    def get_uniq_chars(self):
        char_counts = Counter(self.chars)
        uniq_chars = sorted(char_counts, key=char_counts.get, reverse=True)
        print(f'Unique characters (vocabulary size): {len(uniq_chars)}')
        return uniq_chars

    def get_data(self):
        x,y = [], []
        for index in range(0, len(self.chars_indices)-self.sequence_length, self.sequence_length):
            x.append(np.array(self.chars_indices[index:index+self.sequence_length]))
            y.append(np.array(self.chars_indices[index+1:index+self.sequence_length+1]))

        return  torch.from_numpy(np.array(x)), torch.from_numpy(np.array(y)).long()

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        assert ((idx >= 0) & (idx < len(self.y))), "Dataset index out of range"
        return self.x[idx], self.y[idx]

# %% [markdown]
# Now we can use [`torch.utils.data.Dataloader`](https://pytorch.org/docs/stable/data.html) class to create the PyTorch dataloader.

# %%
# Create the dataset
sequence_length = 100
ShakespeareDataset = DatasetFromTextFile('shakespeare.txt', sequence_length)

print(f'We have {ShakespeareDataset.x.shape[0]} input sequence samples of length {ShakespeareDataset.x.shape[1]} \
and {ShakespeareDataset.y.shape[0]} label sequences of length {ShakespeareDataset.y.shape[1]}')

# Create the Torch DataLoader
batch_size = 64
train_loader = DataLoader(ShakespeareDataset, shuffle=True, batch_size=batch_size, drop_last=True)
# Out:
# Length of text: 1115394 characters
# Unique characters (vocabulary size): 65
# We have 11153 input sequence samples of length 100 and 11153 label sequences of length 100

# %% [markdown]
# ## Build the model
#
# Our model has three layers:
#
# * `torch.nn.Embedding`: The input layer. A trainable lookup table that will map each character-ID (class ID) to a dense vector with `embedding_dim` dimensions;
# * `torch.nn.GRU`: A type of RNN with `hidden_dim` units
# * `torch.nn.Linear`: The output layer, with number of outputs as our vocabulary size (`len(dataset.uniq_chars)`). It outputs one logit for each character in the vocabulary. These are the log-likelihood of each character according to the model.

# %% [markdown]
# For each character the model looks up the embedding, runs the GRU one timestep with the embedding as input, and applies the dense layer to generate logits predicting the log-likelihood of the next character:
#
# ![text_generation_training.png](data:image/png;base64,...)
#
# Image source: http://www.tensorflow.org

# %% [markdown]
# <span style="color:blue">
#
# **Exercise 1:** Complete the code of the `Model` class. You need to embed your input using an `nn.Embedding` layer, create a GRU with `n_layers`, and then compute the output logits.
#
# </span>

# %%
class Model(nn.Module):
    def __init__(self, input_dim, embedding_dim, hidden_dim, output_dim, n_layers, drop_prob=0.):
        super(Model, self).__init__()
        self.hidden_dim = hidden_dim
        self.n_layers = n_layers

        self.embedding = nn.Embedding(input_dim, embedding_dim)
        self.gru = nn.GRU(embedding_dim, hidden_size=hidden_dim, num_layers=n_layers, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)


    def forward(self, x, h):
        emb = self.embedding(x)
        out, h = self.gru(emb, h)
        out = self.fc(out)
        return out, h

    def init_hidden(self, batch_size):
        " Initialize the hidden state of the RNN to zeros"
        hidden = nn.Parameter(torch.zeros(self.n_layers, batch_size, self.hidden_dim))
        return hidden

# %% [markdown]
# Now we can instantiate the model as follows:

# %%
input_dim = len(ShakespeareDataset.uniq_chars)
embedding_dim = 300
hidden_dim = 1024
output_dim = len(ShakespeareDataset.uniq_chars)
n_layers = 2
drop_prob = 0.2

model_sh = Model(input_dim, embedding_dim, hidden_dim, output_dim, n_layers, drop_prob).to(device)

print(model_sh)
# Out:
# Model(
#   (embedding): Embedding(65, 300)
#   (gru): GRU(300, 1024, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=1024, out_features=65, bias=True)
# )

# %% [markdown]
# ## Quick Experiment

# %% [markdown]
# Let's create a string and pass it through our model

# %%
data = torch.tensor([ShakespeareDataset.char_to_index[w] for w in "Hello"])
print(data.shape)
# Out:
# torch.Size([5])

# %% [markdown]
# Our model expects a batch. We will create a batch of 1, using this one data point we have created

# %%
data = data.unsqueeze(0) # this adds one more dimension (the batch one) to our data
print(data.shape)
# Out:
# torch.Size([1, 5])

# %% [markdown]
# Time to pass this through our model. To do so, we need to (1) move our data to the same device like the model and (2) initialise the state of our RNN

# %%
data = data.to(device)
state = model_sh.init_hidden(batch_size = 1) # remember that we will use just a single data point jere
state = state.to(device)
out, state = model_sh(data, state) # The forward pass expects the current state as an argument, and returns the updated state in the output

print(out.shape)
# Out:
# torch.Size([1, 5, 65])

# %% [markdown]
# Our output returns 65 probability values for each character... We need to find which one is the maximum probability for each position, and convert it to the corresponding character

# %%
_, idxs = torch.max(out[0], dim = 1)

print([ShakespeareDataset.index_to_char[int(c)] for c in idxs])
# Out:
# ['&', 'k', 'H', 'H', 'H']

# %% [markdown]
# As expected both inputs and outputs have the same shape, and the predicted characters are just random since the model is not trained yet.

# %% [markdown]
# ## Train the model
#
# Training a language model is essentially a classification problem. Given the previous RNN state, and the input character at this time step, predict the class of the next character.
#
# <span style="color:blue">
#
# **Exercise 2:** which loss function do you think we shall use to train our model?
#
# </span>

# %%
def train(dataloader, model, batch_size, sequence_length, num_epochs):
    model.train()

    criterion =  torch.nn.CrossEntropyLoss(weight=None, size_average=None, ignore_index=-100, reduce=None, reduction='mean', label_smoothing=0.0)
    optimizer = optim.Adam(model.parameters(), lr=0.001)

    losses = []
    for epoch in range(num_epochs):

        for batch, (x, y) in enumerate(dataloader):
            state = model.init_hidden(batch_size) # Start with a new state in each batch
            state = state.to(device)

            x = x.to(device)
            y = y.to(device)
            optimizer.zero_grad()

            y_pred, state = model(x, state)
            loss = criterion(y_pred.transpose(1, 2), y)

            loss.backward()
            optimizer.step()

            if batch%30 == 0:
                print({ 'epoch': epoch, 'batch': batch, 'loss': loss.item() })
                losses.append(loss.item())
    return losses

# %% [markdown]
# Now train the model for 20 epochs and visualize the training loss curve.

# %%
num_epochs = 20

losses = train(train_loader, model_sh, batch_size, sequence_length, num_epochs)
# Out:
# {'epoch': 0, 'batch': 0, 'loss': 4.1835784912109375}
# {'epoch': 0, 'batch': 30, 'loss': 2.259359836578369}
# {'epoch': 0, 'batch': 60, 'loss': 1.9792323112487793}
# {'epoch': 0, 'batch': 90, 'loss': 1.8010127544403076}
# {'epoch': 0, 'batch': 120, 'loss': 1.6763736009597778}
# {'epoch': 0, 'batch': 150, 'loss': 1.6134824752807617}
# {'epoch': 1, 'batch': 0, 'loss': 1.541481375694275}
# {'epoch': 1, 'batch': 30, 'loss': 1.5093122720718384}
# {'epoch': 1, 'batch': 60, 'loss': 1.4713386297225952}
# {'epoch': 1, 'batch': 90, 'loss': 1.4360913038253784}
# {'epoch': 1, 'batch': 120, 'loss': 1.4624725580215454}
# {'epoch': 1, 'batch': 150, 'loss': 1.3956571817398071}
# {'epoch': 2, 'batch': 0, 'loss': 1.3643126487731934}
# {'epoch': 2, 'batch': 30, 'loss': 1.332896113395691}
# {'epoch': 2, 'batch': 60, 'loss': 1.3440076112747192}
# {'epoch': 2, 'batch': 90, 'loss': 1.3514927625656128}
# {'epoch': 2, 'batch': 120, 'loss': 1.3098450899124146}
# {'epoch': 2, 'batch': 150, 'loss': 1.3220785856246948}
# {'epoch': 3, 'batch': 0, 'loss': 1.2979910373687744}
# {'epoch': 3, 'batch': 30, 'loss': 1.2601408958435059}
# {'epoch': 3, 'batch': 60, 'loss': 1.2892858982086182}
# {'epoch': 3, 'batch': 90, 'loss': 1.3256056308746338}
# {'epoch': 3, 'batch': 120, 'loss': 1.303599238395691}
# {'epoch': 3, 'batch': 150, 'loss': 1.2930221557617188}
# {'epoch': 4, 'batch': 0, 'loss': 1.205991506576538}
# {'epoch': 4, 'batch': 30, 'loss': 1.2295509576797485}
# {'epoch': 4, 'batch': 60, 'loss': 1.2148686647415161}
# {'epoch': 4, 'batch': 90, 'loss': 1.2307015657424927}
# {'epoch': 4, 'batch': 120, 'loss': 1.293535590171814}
# {'epoch': 4, 'batch': 150, 'loss': 1.2653652429580688}
# {'epoch': 5, 'batch': 0, 'loss': 1.1651639938354492}
# {'epoch': 5, 'batch': 30, 'loss': 1.1542993783950806}
# {'epoch': 5, 'batch': 60, 'loss': 1.162935733795166}
# {'epoch': 5, 'batch': 90, 'loss': 1.2169344425201416}
# {'epoch': 5, 'batch': 120, 'loss': 1.192022681236267}
# {'epoch': 5, 'batch': 150, 'loss': 1.1876944303512573}
# {'epoch': 6, 'batch': 0, 'loss': 1.1163043975830078}
# {'epoch': 6, 'batch': 30, 'loss': 1.1390819549560547}
# {'epoch': 6, 'batch': 60, 'loss': 1.1368401050567627}
# {'epoch': 6, 'batch': 90, 'loss': 1.1550767421722412}
# {'epoch': 6, 'batch': 120, 'loss': 1.1768308877944946}
# {'epoch': 6, 'batch': 150, 'loss': 1.1671074628829956}
# {'epoch': 7, 'batch': 0, 'loss': 1.0424381494522095}
# {'epoch': 7, 'batch': 30, 'loss': 1.0692718029022217}
# {'epoch': 7, 'batch': 60, 'loss': 1.1103794574737549}
# {'epoch': 7, 'batch': 90, 'loss': 1.0660685300827026}
# {'epoch': 7, 'batch': 120, 'loss': 1.114075779914856}
# {'epoch': 7, 'batch': 150, 'loss': 1.1087539196014404}
# {'epoch': 8, 'batch': 0, 'loss': 1.0024386644363403}
# {'epoch': 8, 'batch': 30, 'loss': 0.9839730858802795}
# {'epoch': 8, 'batch': 60, 'loss': 1.0112793445587158}
# {'epoch': 8, 'batch': 90, 'loss': 1.0375003814697266}
# {'epoch': 8, 'batch': 120, 'loss': 1.0436378717422485}
# {'epoch': 8, 'batch': 150, 'loss': 1.0567132234573364}
# {'epoch': 9, 'batch': 0, 'loss': 0.9989084601402283}
# {'epoch': 9, 'batch': 30, 'loss': 0.960625410079956}
# {'epoch': 9, 'batch': 60, 'loss': 0.9754050374031067}
# {'epoch': 9, 'batch': 90, 'loss': 0.9827468395233154}
# {'epoch': 9, 'batch': 120, 'loss': 0.9850205183029175}
# {'epoch': 9, 'batch': 150, 'loss': 1.018425703048706}
# {'epoch': 10, 'batch': 0, 'loss': 0.8827856183052063}
# {'epoch': 10, 'batch': 30, 'loss': 0.8824208974838257}
# {'epoch': 10, 'batch': 60, 'loss': 0.9630258679389954}
# {'epoch': 10, 'batch': 90, 'loss': 0.9249703288078308}
# {'epoch': 10, 'batch': 120, 'loss': 0.9494374990463257}
# {'epoch': 10, 'batch': 150, 'loss': 0.969878077507019}
# {'epoch': 11, 'batch': 0, 'loss': 0.8489022850990295}
# {'epoch': 11, 'batch': 30, 'loss': 0.8451066017150879}
# {'epoch': 11, 'batch': 60, 'loss': 0.8515123128890991}
# {'epoch': 11, 'batch': 90, 'loss': 0.8955379724502563}
# {'epoch': 11, 'batch': 120, 'loss': 0.8716156482696533}
# {'epoch': 11, 'batch': 150, 'loss': 0.901000440120697}
# {'epoch': 12, 'batch': 0, 'loss': 0.7696381211280823}
# {'epoch': 12, 'batch': 30, 'loss': 0.7880824208259583}
# {'epoch': 12, 'batch': 60, 'loss': 0.7971673011779785}
# {'epoch': 12, 'batch': 90, 'loss': 0.801319420337677}
# {'epoch': 12, 'batch': 120, 'loss': 0.842002809047699}
# {'epoch': 12, 'batch': 150, 'loss': 0.8633689284324646}
# {'epoch': 13, 'batch': 0, 'loss': 0.7145946025848389}
# {'epoch': 13, 'batch': 30, 'loss': 0.723463773727417}
# {'epoch': 13, 'batch': 60, 'loss': 0.7340489029884338}
# {'epoch': 13, 'batch': 90, 'loss': 0.7740983366966248}
# {'epoch': 13, 'batch': 120, 'loss': 0.7778031826019287}
# {'epoch': 13, 'batch': 150, 'loss': 0.8056133985519409}
# {'epoch': 14, 'batch': 0, 'loss': 0.6655404567718506}
# {'epoch': 14, 'batch': 30, 'loss': 0.6896318197250366}
# {'epoch': 14, 'batch': 60, 'loss': 0.6890020966529846}
# {'epoch': 14, 'batch': 90, 'loss': 0.713300347328186}
# {'epoch': 14, 'batch': 120, 'loss': 0.7312731146812439}
# {'epoch': 14, 'batch': 150, 'loss': 0.768705427646637}
# {'epoch': 15, 'batch': 0, 'loss': 0.6236749887466431}
# {'epoch': 15, 'batch': 30, 'loss': 0.6382714509963989}
# {'epoch': 15, 'batch': 60, 'loss': 0.6444838047027588}
# {'epoch': 15, 'batch': 90, 'loss': 0.6542322039604187}
# {'epoch': 15, 'batch': 120, 'loss': 0.6907337307929993}
# {'epoch': 15, 'batch': 150, 'loss': 0.7026521563529968}
# {'epoch': 16, 'batch': 0, 'loss': 0.5786922574043274}
# {'epoch': 16, 'batch': 30, 'loss': 0.602849543094635}
# {'epoch': 16, 'batch': 60, 'loss': 0.5988094806671143}
# {'epoch': 16, 'batch': 90, 'loss': 0.6234889030456543}
# {'epoch': 16, 'batch': 120, 'loss': 0.6460481286048889}
# {'epoch': 16, 'batch': 150, 'loss': 0.6749406456947327}
# {'epoch': 17, 'batch': 0, 'loss': 0.5567342638969421}
# {'epoch': 17, 'batch': 30, 'loss': 0.5629361867904663}
# {'epoch': 17, 'batch': 60, 'loss': 0.5593944191932678}
# {'epoch': 17, 'batch': 90, 'loss': 0.6000154614448547}
# {'epoch': 17, 'batch': 120, 'loss': 0.6252195835113525}
# {'epoch': 17, 'batch': 150, 'loss': 0.6414263248443604}
# {'epoch': 18, 'batch': 0, 'loss': 0.48702770471572876}
# {'epoch': 18, 'batch': 30, 'loss': 0.5122427344322205}
# {'epoch': 18, 'batch': 60, 'loss': 0.5432323813438416}
# {'epoch': 18, 'batch': 90, 'loss': 0.5778555274009705}
# {'epoch': 18, 'batch': 120, 'loss': 0.5885885953903198}
# {'epoch': 18, 'batch': 150, 'loss': 0.61985182762146}
# {'epoch': 19, 'batch': 0, 'loss': 0.48915013670921326}
# {'epoch': 19, 'batch': 30, 'loss': 0.4956996440887451}
# {'epoch': 19, 'batch': 60, 'loss': 0.5384256839752197}
# {'epoch': 19, 'batch': 90, 'loss': 0.5332742929458618}
# {'epoch': 19, 'batch': 120, 'loss': 0.558738112449646}
# {'epoch': 19, 'batch': 150, 'loss': 0.5852948427200317}

# %%
# Visualize the loss evolution during training
plt.plot(losses)
plt.title('Model loss')
plt.show()

# %% [markdown]
# ## Try the trained model
#
# Let's try again to predict some characters given the input sentence 'ROMEO:'. Now the predicted characters should be much better.

# %%
with torch.no_grad():
    input_str = 'ROMEO:'

    state = model_sh.init_hidden(batch_size=1)
    state = state.to(device)
    data = torch.tensor([[ShakespeareDataset.char_to_index[char] for char in input_str]]).to(device)
    output, state = model_sh(data, state)

    _, predicted_idxs = torch.max(output[0], dim = 1)
    predicted_idxs = predicted_idxs.cpu().numpy()

    predicted_str = ''.join([ShakespeareDataset.index_to_char[idx] for idx in predicted_idxs])

    print(f'Input shape: {data.size()}')
    print(f'Output shape: {data.size()}')
    print(f'Input string: {input_str}')
    print(f'Output string: {predicted_str}')
# Out:
# Input shape: torch.Size([1, 6])
# Output shape: torch.Size([1, 6])
# Input string: ROMEO:
# Output string: :MEO:

# %% [markdown]
# ## Generate new text

# %%
def predict(dataset, model, text, next_chars=1000):
    model.eval()

    chars = [char for char in text]
    state = model.init_hidden(1)
    state = state.to(device)

    # we start by feeding all the input characters to our model
    x = torch.tensor([dataset.char_to_index[char] for char in chars])
    x = x.unsqueeze(0) # create a batch of 1
    x = x.to(device)

    for i in range(0, next_chars):

        y_pred, state = model(x, state)

        last_char_logits = y_pred[0][-1]
        p = torch.nn.functional.softmax(last_char_logits, dim=0).detach().cpu().numpy()
        char_index = np.random.choice(len(last_char_logits), p=p)
        chars.append(dataset.index_to_char[char_index])

        # the output of the model (a single character index) becomes the input at next iteration
        x = torch.tensor([[char_index]])
        x = x.to(device)

    return chars

predicted = predict(ShakespeareDataset, model_sh,'ROMEO:')
print(''.join(predicted))
# Out:
# ROMEO:
# I come: but is this introllary
# Is prisoner to the wall; this morning comes a pronounce
# Or by the entrails of your bearing reigns.
#
# DUKE VINCENTIO:
# In troth, sir, to my knowledge.
#
# GLOUCESTER:
# Good morrow, neighbour Grumio. Get you on:
# The base knave and nobleness to death,
# That ever I saw for me and here
# am I will perceive them. Come, valiant, and
# The which your love sack the crown and death:
# Thus with a martial scorn, and friends, though I
# fall to the very noble house of any linger
# And make her eyes under me.
#
# BISHOP OF ELY:
# Yea, at the morning.
#
# CORIOLANUS:
# Why there is Barnardine?
#
# Messenger:
# My lord, I come, my lord.
#
# LEONTES:
# I hear, my lord,
# Will you take to follow you to woo thee?
# Decome of Buckingham!
#
# LUCENTIO:
# Tranio! then have I choose our human spoke,
# I have a bottom of the many head to thee.
#
# JULIET:
# What sayest thou? the sun swar's ear, hath drawn,
# A serpent that makes from Tyberty
# England hath best accuseth his traitor:
# What enemy, the imposed infection
# a thousand rebus

# %% [markdown]
# While some of the sentences are grammatically correct, most do not make sense. The model has not learned the meaning of words (we would need a much larger corpus for that, and probably a word level language model), but consider the following:
#
# * The model is character-based. When training started, the model did not know how to spell an English word, or that words were even a unit of text. Now it does a pretty decent job on spelling.
#
# * The structure of the output resembles a play, blocks of text generally begin with a speaker name, in all capital letters similar to the dataset.
#
# * The model is trained on small batches of text (100 characters each), and is still able to generate a longer sequence of text with coherent structure.

# %% [markdown]
# # Homework
#
# <span style="color:blue">
#
# **Exercise 3:** Build two new models: one using Simple RNN cells (torch.nn.RNN) instead of GRUs(torch.nn.RNN), and the other using LSTMs (torch.nn.LSTM). Train all three models (GRU, LSTM, SimpleRNN) for 30 epochs and compare the loss curves. You can optionally try different configurations: embedding dimension, hidden layers dimensions, number of layers, etc.
#
# </span>

# %%
#GRU model for 30 epochs.
losses_gru = train(train_loader, model_sh, batch_size, sequence_length, num_epochs=30)
# Out:
# {'epoch': 0, 'batch': 0, 'loss': 0.48318400979042053}
# {'epoch': 0, 'batch': 30, 'loss': 0.4768119156360626}
# {'epoch': 0, 'batch': 60, 'loss': 0.4615538716316223}
# {'epoch': 0, 'batch': 90, 'loss': 0.4689241349697113}
# {'epoch': 0, 'batch': 120, 'loss': 0.4972587823867798}
# {'epoch': 0, 'batch': 150, 'loss': 0.4898429811000824}
# {'epoch': 1, 'batch': 0, 'loss': 0.3657833933830261}
# {'epoch': 1, 'batch': 30, 'loss': 0.37698203325271606}
# {'epoch': 1, 'batch': 60, 'loss': 0.4000626802444458}
# {'epoch': 1, 'batch': 90, 'loss': 0.39725902676582336}
# {'epoch': 1, 'batch': 120, 'loss': 0.4269641041755676}
# {'epoch': 1, 'batch': 150, 'loss': 0.463504821062088}
# {'epoch': 2, 'batch': 0, 'loss': 0.34893572330474854}
# {'epoch': 2, 'batch': 30, 'loss': 0.36112892627716064}
# {'epoch': 2, 'batch': 60, 'loss': 0.3717060089111328}
# {'epoch': 2, 'batch': 90, 'loss': 0.3914654850959778}
# {'epoch': 2, 'batch': 120, 'loss': 0.429299533367157}
# {'epoch': 2, 'batch': 150, 'loss': 0.43795526027679443}
# {'epoch': 3, 'batch': 0, 'loss': 0.33063197135925293}
# {'epoch': 3, 'batch': 30, 'loss': 0.35492047667503357}
# {'epoch': 3, 'batch': 60, 'loss': 0.3636131286621094}
# {'epoch': 3, 'batch': 90, 'loss': 0.3806634843349457}
# {'epoch': 3, 'batch': 120, 'loss': 0.39575454592704773}
# {'epoch': 3, 'batch': 150, 'loss': 0.44142186641693115}
# {'epoch': 4, 'batch': 0, 'loss': 0.31886279582977295}
# {'epoch': 4, 'batch': 30, 'loss': 0.35070496797561646}
# {'epoch': 4, 'batch': 60, 'loss': 0.36569368839263916}
# {'epoch': 4, 'batch': 90, 'loss': 0.39444592595100403}
# {'epoch': 4, 'batch': 120, 'loss': 0.40262076258659363}
# {'epoch': 4, 'batch': 150, 'loss': 0.44712382555007935}
# {'epoch': 5, 'batch': 0, 'loss': 0.33473503589630127}
# {'epoch': 5, 'batch': 30, 'loss': 0.34573307633399963}
# {'epoch': 5, 'batch': 60, 'loss': 0.3624037504196167}
# {'epoch': 5, 'batch': 90, 'loss': 0.3777754306793213}
# {'epoch': 5, 'batch': 120, 'loss': 0.39753255248069763}
# {'epoch': 5, 'batch': 150, 'loss': 0.4409346878528595}
# {'epoch': 6, 'batch': 0, 'loss': 0.34841403365135193}
# {'epoch': 6, 'batch': 30, 'loss': 0.3518455922603607}
# {'epoch': 6, 'batch': 60, 'loss': 0.37751030921936035}
# {'epoch': 6, 'batch': 90, 'loss': 0.3912501931190491}
# {'epoch': 6, 'batch': 120, 'loss': 0.41918617486953735}
# {'epoch': 6, 'batch': 150, 'loss': 0.43074172735214233}
# {'epoch': 7, 'batch': 0, 'loss': 0.35736048221588135}
# {'epoch': 7, 'batch': 30, 'loss': 0.35319286584854126}
# {'epoch': 7, 'batch': 60, 'loss': 0.37115925550460815}
# {'epoch': 7, 'batch': 90, 'loss': 0.4009433388710022}
# {'epoch': 7, 'batch': 120, 'loss': 0.421146035194397}
# {'epoch': 7, 'batch': 150, 'loss': 0.4367099404335022}
# {'epoch': 8, 'batch': 0, 'loss': 0.34190747141838074}
# {'epoch': 8, 'batch': 30, 'loss': 0.3674565851688385}
# {'epoch': 8, 'batch': 60, 'loss': 0.36952751874923706}
# {'epoch': 8, 'batch': 90, 'loss': 0.3985145092010498}
# {'epoch': 8, 'batch': 120, 'loss': 0.4137508273124695}
# {'epoch': 8, 'batch': 150, 'loss': 0.4502711594104767}
# {'epoch': 9, 'batch': 0, 'loss': 0.34382525086402893}
# {'epoch': 9, 'batch': 30, 'loss': 0.3621026873588562}
# {'epoch': 9, 'batch': 60, 'loss': 0.38589873909950256}
# {'epoch': 9, 'batch': 90, 'loss': 0.3987775444984436}
# {'epoch': 9, 'batch': 120, 'loss': 0.42807456851005554}
# {'epoch': 9, 'batch': 150, 'loss': 0.4246668219566345}
# {'epoch': 10, 'batch': 0, 'loss': 0.3275165855884552}
# {'epoch': 10, 'batch': 30, 'loss': 0.3520243763923645}
# {'epoch': 10, 'batch': 60, 'loss': 0.366524875164032}
# {'epoch': 10, 'batch': 90, 'loss': 0.39524102210998535}
# {'epoch': 10, 'batch': 120, 'loss': 0.4256933629512787}
# {'epoch': 10, 'batch': 150, 'loss': 0.43581053614616394}
# {'epoch': 11, 'batch': 0, 'loss': 0.33751818537712097}
# {'epoch': 11, 'batch': 30, 'loss': 0.35227975249290466}
# {'epoch': 11, 'batch': 60, 'loss': 0.3652767837047577}
# {'epoch': 11, 'batch': 90, 'loss': 0.3926374316215515}
# {'epoch': 11, 'batch': 120, 'loss': 0.4118683338165283}
# {'epoch': 11, 'batch': 150, 'loss': 0.45413511991500854}
# {'epoch': 12, 'batch': 0, 'loss': 0.3528282046318054}
# {'epoch': 12, 'batch': 30, 'loss': 0.36825233697891235}
# {'epoch': 12, 'batch': 60, 'loss': 0.3827526867389679}
# {'epoch': 12, 'batch': 90, 'loss': 0.39525315165519714}
# {'epoch': 12, 'batch': 120, 'loss': 0.4389234185218811}
# {'epoch': 12, 'batch': 150, 'loss': 0.4347931146621704}
# {'epoch': 13, 'batch': 0, 'loss': 0.34233787655830383}
# {'epoch': 13, 'batch': 30, 'loss': 0.3859313130378723}
# {'epoch': 13, 'batch': 60, 'loss': 0.3983616530895233}
# {'epoch': 13, 'batch': 90, 'loss': 0.416402131319046}
# {'epoch': 13, 'batch': 120, 'loss': 0.42820000648498535}
# {'epoch': 13, 'batch': 150, 'loss': 0.4481827914714813}
# {'epoch': 14, 'batch': 0, 'loss': 0.3428357243537903}
# {'epoch': 14, 'batch': 30, 'loss': 0.3875845670700073}
# {'epoch': 14, 'batch': 60, 'loss': 0.40213263034820557}
# {'epoch': 14, 'batch': 90, 'loss': 0.42140498757362366}
# {'epoch': 14, 'batch': 120, 'loss': 0.4430544376373291}
# {'epoch': 14, 'batch': 150, 'loss': 0.4736056625843048}
# {'epoch': 15, 'batch': 0, 'loss': 0.36111077666282654}
# {'epoch': 15, 'batch': 30, 'loss': 0.3960374891757965}
# {'epoch': 15, 'batch': 60, 'loss': 0.402328222990036}
# {'epoch': 15, 'batch': 90, 'loss': 0.42355403304100037}
# {'epoch': 15, 'batch': 120, 'loss': 0.4459942579269409}
# {'epoch': 15, 'batch': 150, 'loss': 0.4732500910758972}
# {'epoch': 16, 'batch': 0, 'loss': 0.3791646659374237}
# {'epoch': 16, 'batch': 30, 'loss': 0.40066829323768616}
# {'epoch': 16, 'batch': 60, 'loss': 0.4012283980846405}
# {'epoch': 16, 'batch': 90, 'loss': 0.4329155683517456}
# {'epoch': 16, 'batch': 120, 'loss': 0.44376084208488464}
# {'epoch': 16, 'batch': 150, 'loss': 0.46325284242630005}
# {'epoch': 17, 'batch': 0, 'loss': 0.3629070222377777}
# {'epoch': 17, 'batch': 30, 'loss': 0.38628777861595154}
# {'epoch': 17, 'batch': 60, 'loss': 0.4256407916545868}
# {'epoch': 17, 'batch': 90, 'loss': 0.4118131697177887}
# {'epoch': 17, 'batch': 120, 'loss': 0.45793166756629944}
# {'epoch': 17, 'batch': 150, 'loss': 0.47737398743629456}
# {'epoch': 18, 'batch': 0, 'loss': 0.38427746295928955}
# {'epoch': 18, 'batch': 30, 'loss': 0.39611682295799255}
# {'epoch': 18, 'batch': 60, 'loss': 0.41243812441825867}
# {'epoch': 18, 'batch': 90, 'loss': 0.441106379032135}
# {'epoch': 18, 'batch': 120, 'loss': 0.44748589396476746}
# {'epoch': 18, 'batch': 150, 'loss': 0.4938722848892212}
# {'epoch': 19, 'batch': 0, 'loss': 0.380828857421875}
# {'epoch': 19, 'batch': 30, 'loss': 0.4167495667934418}
# {'epoch': 19, 'batch': 60, 'loss': 0.4233017861843109}
# {'epoch': 19, 'batch': 90, 'loss': 0.4409964680671692}
# {'epoch': 19, 'batch': 120, 'loss': 0.4761252999305725}
# {'epoch': 19, 'batch': 150, 'loss': 0.505407452583313}
# {'epoch': 20, 'batch': 0, 'loss': 0.3975270092487335}
# {'epoch': 20, 'batch': 30, 'loss': 0.40457379817962646}
# {'epoch': 20, 'batch': 60, 'loss': 0.4299982488155365}
# {'epoch': 20, 'batch': 90, 'loss': 0.45058220624923706}
# {'epoch': 20, 'batch': 120, 'loss': 0.47388744354248047}
# {'epoch': 20, 'batch': 150, 'loss': 0.5004379153251648}
# {'epoch': 21, 'batch': 0, 'loss': 0.39703288674354553}
# {'epoch': 21, 'batch': 30, 'loss': 0.4173698127269745}
# {'epoch': 21, 'batch': 60, 'loss': 0.4413306415081024}
# {'epoch': 21, 'batch': 90, 'loss': 0.48555296659469604}
# {'epoch': 21, 'batch': 120, 'loss': 0.48109903931617737}
# {'epoch': 21, 'batch': 150, 'loss': 0.5124480128288269}
# {'epoch': 22, 'batch': 0, 'loss': 0.40964409708976746}
# {'epoch': 22, 'batch': 30, 'loss': 0.4407356381416321}
# {'epoch': 22, 'batch': 60, 'loss': 0.4538748264312744}
# {'epoch': 22, 'batch': 90, 'loss': 0.4680768847465515}
# {'epoch': 22, 'batch': 120, 'loss': 0.5069703459739685}
# {'epoch': 22, 'batch': 150, 'loss': 0.5406519770622253}
# {'epoch': 23, 'batch': 0, 'loss': 0.43062758445739746}
# {'epoch': 23, 'batch': 30, 'loss': 0.4379243850708008}
# {'epoch': 23, 'batch': 60, 'loss': 0.47955748438835144}
# {'epoch': 23, 'batch': 90, 'loss': 0.4787285625934601}
# {'epoch': 23, 'batch': 120, 'loss': 0.5082830786705017}
# {'epoch': 23, 'batch': 150, 'loss': 0.5509471893310547}
# {'epoch': 24, 'batch': 0, 'loss': 0.42505356669425964}
# {'epoch': 24, 'batch': 30, 'loss': 0.46282732486724854}
# {'epoch': 24, 'batch': 60, 'loss': 0.4990043342113495}
# {'epoch': 24, 'batch': 90, 'loss': 0.5137842297554016}
# {'epoch': 24, 'batch': 120, 'loss': 0.5300575494766235}
# {'epoch': 24, 'batch': 150, 'loss': 0.5519868731498718}
# {'epoch': 25, 'batch': 0, 'loss': 0.4724557399749756}
# {'epoch': 25, 'batch': 30, 'loss': 0.4783248007297516}
# {'epoch': 25, 'batch': 60, 'loss': 0.4853948652744293}
# {'epoch': 25, 'batch': 90, 'loss': 0.5181556940078735}
# {'epoch': 25, 'batch': 120, 'loss': 0.5459482669830322}
# {'epoch': 25, 'batch': 150, 'loss': 0.5721402168273926}
# {'epoch': 26, 'batch': 0, 'loss': 0.4414904713630676}
# {'epoch': 26, 'batch': 30, 'loss': 0.47441765666007996}
# {'epoch': 26, 'batch': 60, 'loss': 0.5191003680229187}
# {'epoch': 26, 'batch': 90, 'loss': 0.5307416319847107}
# {'epoch': 26, 'batch': 120, 'loss': 0.5578227639198303}
# {'epoch': 26, 'batch': 150, 'loss': 0.5879251956939697}
# {'epoch': 27, 'batch': 0, 'loss': 0.4769335091114044}
# {'epoch': 27, 'batch': 30, 'loss': 0.5020759701728821}
# {'epoch': 27, 'batch': 60, 'loss': 0.5013319849967957}
# {'epoch': 27, 'batch': 90, 'loss': 0.5516994595527649}
# {'epoch': 27, 'batch': 120, 'loss': 0.5618493556976318}
# {'epoch': 27, 'batch': 150, 'loss': 0.5819510221481323}
# {'epoch': 28, 'batch': 0, 'loss': 0.4664495587348938}
# {'epoch': 28, 'batch': 30, 'loss': 0.5008103847503662}
# {'epoch': 28, 'batch': 60, 'loss': 0.5326656699180603}
# {'epoch': 28, 'batch': 90, 'loss': 0.5628112554550171}
# {'epoch': 28, 'batch': 120, 'loss': 0.5825523138046265}
# {'epoch': 28, 'batch': 150, 'loss': 0.610196053981781}
# {'epoch': 29, 'batch': 0, 'loss': 0.4861455261707306}
# {'epoch': 29, 'batch': 30, 'loss': 0.5257581472396851}
# {'epoch': 29, 'batch': 60, 'loss': 0.5500733852386475}
# {'epoch': 29, 'batch': 90, 'loss': 0.5661303997039795}
# {'epoch': 29, 'batch': 120, 'loss': 0.5722588896751404}
# {'epoch': 29, 'batch': 150, 'loss': 0.6240671277046204}

# %%
class RNN_Simple(nn.Module):

  def __init__(self, input_dim, embedding_dim, hidden_dim, output_dim, n_layers, drop_prob=0.):
        super(RNN_Simple, self).__init__()
        self.hidden_dim = hidden_dim
        self.n_layers = n_layers

        self.embedding = torch.nn.Embedding(input_dim, embedding_dim)
        self.rnn = torch.nn.RNN(embedding_dim, hidden_size=hidden_dim, num_layers=n_layers, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)

  def forward(self, x, h):
      emb = self.embedding(x)
      out, h = self.rnn(emb, h)
      out = self.fc(out)
      return out, h

  def init_hidden(self, batch_size):
      hidden = torch.zeros(self.n_layers, batch_size, self.hidden_dim)
      return hidden

model_rnn_simple = RNN_Simple(input_dim, embedding_dim, hidden_dim, output_dim, n_layers, drop_prob).to(device)

# %%
#RNN simple model for 30 epochs.
losses_rnn = train(train_loader, model_rnn_simple, batch_size, sequence_length, num_epochs=30)
# Out:
# {'epoch': 0, 'batch': 0, 'loss': 4.18989372253418}
# {'epoch': 0, 'batch': 30, 'loss': 2.200343370437622}
# {'epoch': 0, 'batch': 60, 'loss': 2.0033347606658936}
# {'epoch': 0, 'batch': 90, 'loss': 1.8715509176254272}
# {'epoch': 0, 'batch': 120, 'loss': 1.7748708724975586}
# {'epoch': 0, 'batch': 150, 'loss': 1.7056869268417358}
# {'epoch': 1, 'batch': 0, 'loss': 1.6808385848999023}
# {'epoch': 1, 'batch': 30, 'loss': 1.6279529333114624}
# {'epoch': 1, 'batch': 60, 'loss': 1.6452717781066895}
# {'epoch': 1, 'batch': 90, 'loss': 1.5767579078674316}
# {'epoch': 1, 'batch': 120, 'loss': 1.5289392471313477}
# {'epoch': 1, 'batch': 150, 'loss': 1.5329035520553589}
# {'epoch': 2, 'batch': 0, 'loss': 1.494868278503418}
# {'epoch': 2, 'batch': 30, 'loss': 1.4542210102081299}
# {'epoch': 2, 'batch': 60, 'loss': 1.4494738578796387}
# {'epoch': 2, 'batch': 90, 'loss': 1.4892216920852661}
# {'epoch': 2, 'batch': 120, 'loss': 1.4494349956512451}
# {'epoch': 2, 'batch': 150, 'loss': 1.464614748954773}
# {'epoch': 3, 'batch': 0, 'loss': 1.4140986204147339}
# {'epoch': 3, 'batch': 30, 'loss': 1.3713407516479492}
# {'epoch': 3, 'batch': 60, 'loss': 1.4120842218399048}
# {'epoch': 3, 'batch': 90, 'loss': 1.4092669486999512}
# {'epoch': 3, 'batch': 120, 'loss': 1.381173849105835}
# {'epoch': 3, 'batch': 150, 'loss': 1.3985399007797241}
# {'epoch': 4, 'batch': 0, 'loss': 1.3988003730773926}
# {'epoch': 4, 'batch': 30, 'loss': 1.351704716682434}
# {'epoch': 4, 'batch': 60, 'loss': 1.3433630466461182}
# {'epoch': 4, 'batch': 90, 'loss': 1.3384627103805542}
# {'epoch': 4, 'batch': 120, 'loss': 1.3611375093460083}
# {'epoch': 4, 'batch': 150, 'loss': 1.3838679790496826}
# {'epoch': 5, 'batch': 0, 'loss': 1.2627310752868652}
# {'epoch': 5, 'batch': 30, 'loss': 1.2763266563415527}
# {'epoch': 5, 'batch': 60, 'loss': 1.3573437929153442}
# {'epoch': 5, 'batch': 90, 'loss': 1.3275915384292603}
# {'epoch': 5, 'batch': 120, 'loss': 1.3104060888290405}
# {'epoch': 5, 'batch': 150, 'loss': 1.3505724668502808}
# {'epoch': 6, 'batch': 0, 'loss': 1.249287724494934}
# {'epoch': 6, 'batch': 30, 'loss': 1.2618979215621948}
# {'epoch': 6, 'batch': 60, 'loss': 1.2720272541046143}
# {'epoch': 6, 'batch': 90, 'loss': 1.3254870176315308}
# {'epoch': 6, 'batch': 120, 'loss': 1.291192650794983}
# {'epoch': 6, 'batch': 150, 'loss': 1.2715187072753906}
# {'epoch': 7, 'batch': 0, 'loss': 1.2649656534194946}
# {'epoch': 7, 'batch': 30, 'loss': 1.2382993698120117}
# {'epoch': 7, 'batch': 60, 'loss': 1.2814793586730957}
# {'epoch': 7, 'batch': 90, 'loss': 1.2384427785873413}
# {'epoch': 7, 'batch': 120, 'loss': 1.2881861925125122}
# {'epoch': 7, 'batch': 150, 'loss': 1.2564479112625122}
# {'epoch': 8, 'batch': 0, 'loss': 1.2564600706100464}
# {'epoch': 8, 'batch': 30, 'loss': 1.249626874923706}
# {'epoch': 8, 'batch': 60, 'loss': 1.267889380455017}
# {'epoch': 8, 'batch': 90, 'loss': 1.2400610446929932}
# {'epoch': 8, 'batch': 120, 'loss': 1.2526192665100098}
# {'epoch': 8, 'batch': 150, 'loss': 1.2692782878875732}
# {'epoch': 9, 'batch': 0, 'loss': 1.198482871055603}
# {'epoch': 9, 'batch': 30, 'loss': 1.224329948425293}
# {'epoch': 9, 'batch': 60, 'loss': 1.2239516973495483}
# {'epoch': 9, 'batch': 90, 'loss': 1.2607625722885132}
# {'epoch': 9, 'batch': 120, 'loss': 1.2570834159851074}
# {'epoch': 9, 'batch': 150, 'loss': 1.2555038928985596}
# {'epoch': 10, 'batch': 0, 'loss': 1.1467010974884033}
# {'epoch': 10, 'batch': 30, 'loss': 1.1780333518981934}
# {'epoch': 10, 'batch': 60, 'loss': 1.1827572584152222}
# {'epoch': 10, 'batch': 90, 'loss': 1.2111130952835083}
# {'epoch': 10, 'batch': 120, 'loss': 1.2404195070266724}
# {'epoch': 10, 'batch': 150, 'loss': 1.2277724742889404}
# {'epoch': 11, 'batch': 0, 'loss': 1.1839553117752075}
# {'epoch': 11, 'batch': 30, 'loss': 1.1792407035827637}
# {'epoch': 11, 'batch': 60, 'loss': 1.1767293214797974}
# {'epoch': 11, 'batch': 90, 'loss': 1.1838994026184082}
# {'epoch': 11, 'batch': 120, 'loss': 1.1761956214904785}
# {'epoch': 11, 'batch': 150, 'loss': 1.1928600072860718}
# {'epoch': 12, 'batch': 0, 'loss': 1.084949254989624}
# {'epoch': 12, 'batch': 30, 'loss': 1.1484240293502808}
# {'epoch': 12, 'batch': 60, 'loss': 1.1480627059936523}
# {'epoch': 12, 'batch': 90, 'loss': 1.1693041324615479}
# {'epoch': 12, 'batch': 120, 'loss': 1.1977744102478027}
# {'epoch': 12, 'batch': 150, 'loss': 1.1430648565292358}
# {'epoch': 13, 'batch': 0, 'loss': 1.122002124786377}
# {'epoch': 13, 'batch': 30, 'loss': 1.1475428342819214}
# {'epoch': 13, 'batch': 60, 'loss': 1.1549983024597168}
# {'epoch': 13, 'batch': 90, 'loss': 1.1682710647583008}
# {'epoch': 13, 'batch': 120, 'loss': 1.1279282569885254}
# {'epoch': 13, 'batch': 150, 'loss': 1.1594966650009155}
# {'epoch': 14, 'batch': 0, 'loss': 1.0783751010894775}
# {'epoch': 14, 'batch': 30, 'loss': 1.1418153047561646}
# {'epoch': 14, 'batch': 60, 'loss': 1.1166385412216187}
# {'epoch': 14, 'batch': 90, 'loss': 1.1200311183929443}
# {'epoch': 14, 'batch': 120, 'loss': 1.1594730615615845}
# {'epoch': 14, 'batch': 150, 'loss': 1.1438490152359009}
# {'epoch': 15, 'batch': 0, 'loss': 1.081368327140808}
# {'epoch': 15, 'batch': 30, 'loss': 1.0944496393203735}
# {'epoch': 15, 'batch': 60, 'loss': 1.0904991626739502}
# {'epoch': 15, 'batch': 90, 'loss': 1.1040290594100952}
# {'epoch': 15, 'batch': 120, 'loss': 1.1446679830551147}
# {'epoch': 15, 'batch': 150, 'loss': 1.1230063438415527}
# {'epoch': 16, 'batch': 0, 'loss': 1.0312834978103638}
# {'epoch': 16, 'batch': 30, 'loss': 1.0701184272766113}
# {'epoch': 16, 'batch': 60, 'loss': 1.0881537199020386}
# {'epoch': 16, 'batch': 90, 'loss': 1.1161977052688599}
# {'epoch': 16, 'batch': 120, 'loss': 1.118141770362854}
# {'epoch': 16, 'batch': 150, 'loss': 1.0956820249557495}
# {'epoch': 17, 'batch': 0, 'loss': 1.047235131263733}
# {'epoch': 17, 'batch': 30, 'loss': 1.0725876092910767}
# {'epoch': 17, 'batch': 60, 'loss': 1.0712971687316895}
# {'epoch': 17, 'batch': 90, 'loss': 1.0615911483764648}
# {'epoch': 17, 'batch': 120, 'loss': 1.084587574005127}
# {'epoch': 17, 'batch': 150, 'loss': 1.1210389137268066}
# {'epoch': 18, 'batch': 0, 'loss': 1.0208081007003784}
# {'epoch': 18, 'batch': 30, 'loss': 1.0108376741409302}
# {'epoch': 18, 'batch': 60, 'loss': 1.052657961845398}
# {'epoch': 18, 'batch': 90, 'loss': 1.057550311088562}
# {'epoch': 18, 'batch': 120, 'loss': 1.0368157625198364}
# {'epoch': 18, 'batch': 150, 'loss': 1.0544095039367676}
# {'epoch': 19, 'batch': 0, 'loss': 1.0197017192840576}
# {'epoch': 19, 'batch': 30, 'loss': 1.0386277437210083}
# {'epoch': 19, 'batch': 60, 'loss': 1.0130068063735962}
# {'epoch': 19, 'batch': 90, 'loss': 1.0707892179489136}
# {'epoch': 19, 'batch': 120, 'loss': 1.0823931694030762}
# {'epoch': 19, 'batch': 150, 'loss': 1.0771362781524658}
# {'epoch': 20, 'batch': 0, 'loss': 1.001473069190979}
# {'epoch': 20, 'batch': 30, 'loss': 0.9773445129394531}
# {'epoch': 20, 'batch': 60, 'loss': 1.0190930366516113}
# {'epoch': 20, 'batch': 90, 'loss': 1.0458053350448608}
# {'epoch': 20, 'batch': 120, 'loss': 1.0461795330047607}
# {'epoch': 20, 'batch': 150, 'loss': 1.0715298652648926}
# {'epoch': 21, 'batch': 0, 'loss': 0.9804192185401917}
# {'epoch': 21, 'batch': 30, 'loss': 1.011908769607544}
# {'epoch': 21, 'batch': 60, 'loss': 1.0075451135635376}
# {'epoch': 21, 'batch': 90, 'loss': 1.030369758605957}
# {'epoch': 21, 'batch': 120, 'loss': 1.0335941314697266}
# {'epoch': 21, 'batch': 150, 'loss': 1.0861499309539795}
# {'epoch': 22, 'batch': 0, 'loss': 0.9761600494384766}
# {'epoch': 22, 'batch': 30, 'loss': 0.9662377834320068}
# {'epoch': 22, 'batch': 60, 'loss': 0.9851139783859253}
# {'epoch': 22, 'batch': 90, 'loss': 1.0151413679122925}
# {'epoch': 22, 'batch': 120, 'loss': 1.0324996709823608}
# {'epoch': 22, 'batch': 150, 'loss': 1.0492448806762695}
# {'epoch': 23, 'batch': 0, 'loss': 0.9820529818534851}
# {'epoch': 23, 'batch': 30, 'loss': 0.9538375735282898}
# {'epoch': 23, 'batch': 60, 'loss': 0.9831427931785583}
# {'epoch': 23, 'batch': 90, 'loss': 0.9935904145240784}
# {'epoch': 23, 'batch': 120, 'loss': 1.0158530473709106}
# {'epoch': 23, 'batch': 150, 'loss': 1.0281449556350708}
# {'epoch': 24, 'batch': 0, 'loss': 0.957725465297699}
# {'epoch': 24, 'batch': 30, 'loss': 0.9555532932281494}
# {'epoch': 24, 'batch': 60, 'loss': 0.9928997755050659}
# {'epoch': 24, 'batch': 90, 'loss': 0.9858381152153015}
# {'epoch': 24, 'batch': 120, 'loss': 0.9704494476318359}
# {'epoch': 24, 'batch': 150, 'loss': 0.9998510479927063}
# {'epoch': 25, 'batch': 0, 'loss': 0.9178426265716553}
# {'epoch': 25, 'batch': 30, 'loss': 0.9558122158050537}
# {'epoch': 25, 'batch': 60, 'loss': 0.9523570537567139}
# {'epoch': 25, 'batch': 90, 'loss': 0.9592493176460266}
# {'epoch': 25, 'batch': 120, 'loss': 0.9691492319107056}
# {'epoch': 25, 'batch': 150, 'loss': 1.0033773183822632}
# {'epoch': 26, 'batch': 0, 'loss': 0.9241448044776917}
# {'epoch': 26, 'batch': 30, 'loss': 0.9485037922859192}
# {'epoch': 26, 'batch': 60, 'loss': 0.9432219862937927}
# {'epoch': 26, 'batch': 90, 'loss': 0.9868305921554565}
# {'epoch': 26, 'batch': 120, 'loss': 0.9839510321617126}
# {'epoch': 26, 'batch': 150, 'loss': 0.9843565225601196}
# {'epoch': 27, 'batch': 0, 'loss': 0.9267595410346985}
# {'epoch': 27, 'batch': 30, 'loss': 0.9178251624107361}
# {'epoch': 27, 'batch': 60, 'loss': 0.9286355376243591}
# {'epoch': 27, 'batch': 90, 'loss': 0.9359028339385986}
# {'epoch': 27, 'batch': 120, 'loss': 0.9464865922927856}
# {'epoch': 27, 'batch': 150, 'loss': 0.9652903079986572}
# {'epoch': 28, 'batch': 0, 'loss': 0.9202911853790283}
# {'epoch': 28, 'batch': 30, 'loss': 0.9152212738990784}
# {'epoch': 28, 'batch': 60, 'loss': 0.9281406998634338}
# {'epoch': 28, 'batch': 90, 'loss': 0.944389283657074}
# {'epoch': 28, 'batch': 120, 'loss': 0.9833658337593079}
# {'epoch': 28, 'batch': 150, 'loss': 0.9640374183654785}
# {'epoch': 29, 'batch': 0, 'loss': 0.9041491150856018}
# {'epoch': 29, 'batch': 30, 'loss': 0.9284572005271912}
# {'epoch': 29, 'batch': 60, 'loss': 0.9098132252693176}
# {'epoch': 29, 'batch': 90, 'loss': 0.9533846974372864}
# {'epoch': 29, 'batch': 120, 'loss': 0.9493091106414795}
# {'epoch': 29, 'batch': 150, 'loss': 0.965401828289032}

# %%
#We need to make changes to the training function specifically for the LSTM.
def train_LSTM(dataloader, model, batch_size, sequence_length, num_epochs):
    model.train()

    criterion = torch.nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001)

    losses = []
    for epoch in range(num_epochs):
        for batch, (x, y) in enumerate(dataloader):
            state = model.init_hidden(batch_size) # Starting with a new state each epoch.
            state = tuple(s.to(device) for s in state)

            x = x.to(device)
            y = y.to(device)
            optimizer.zero_grad()

            y_pred, state = model(x, state)
            loss = criterion(y_pred.transpose(1, 2), y)

            loss.backward()
            optimizer.step()

            if batch % 30 == 0:
                print({ 'epoch': epoch, 'batch': batch, 'loss': loss.item() })
                losses.append(loss.item())
    return losses

# %%
class model_LSTM(nn.Module):
    def __init__(self, input_dim, embedding_dim, hidden_dim, output_dim, n_layers, drop_prob=0.):
        super(model_LSTM, self).__init__()
        self.hidden_dim = hidden_dim
        self.n_layers = n_layers

        self.embedding = torch.nn.Embedding(input_dim, embedding_dim)
        self.lstm = torch.nn.LSTM(embedding_dim, hidden_size=hidden_dim, num_layers=n_layers, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, x, h):
        emb = self.embedding(x)
        out, h = self.lstm(emb, h)
        out = self.fc(out)
        return out, h

    def init_hidden(self, batch_size):
        hidden = (torch.zeros(self.n_layers, batch_size, self.hidden_dim), torch.zeros(self.n_layers, batch_size, self.hidden_dim))
        return hidden

# %%
model_lstm_simple = model_LSTM(input_dim, embedding_dim, hidden_dim, output_dim, n_layers, drop_prob).to(device)

# %%
lossesLSTM = train_LSTM(train_loader, model_lstm_simple, batch_size, sequence_length, num_epochs=30)
# Out:
# {'epoch': 0, 'batch': 0, 'loss': 4.170600414276123}
# {'epoch': 0, 'batch': 30, 'loss': 2.3800601959228516}
# {'epoch': 0, 'batch': 60, 'loss': 2.023085832595825}
# {'epoch': 0, 'batch': 90, 'loss': 1.829919695854187}
# {'epoch': 0, 'batch': 120, 'loss': 1.6908791065216064}
# {'epoch': 0, 'batch': 150, 'loss': 1.6033799648284912}
# {'epoch': 1, 'batch': 0, 'loss': 1.5203444957733154}
# {'epoch': 1, 'batch': 30, 'loss': 1.506777048110962}
# {'epoch': 1, 'batch': 60, 'loss': 1.4101219177246094}
# {'epoch': 1, 'batch': 90, 'loss': 1.4282279014587402}
# {'epoch': 1, 'batch': 120, 'loss': 1.4242459535598755}
# {'epoch': 1, 'batch': 150, 'loss': 1.4174489974975586}
# {'epoch': 2, 'batch': 0, 'loss': 1.3190287351608276}
# {'epoch': 2, 'batch': 30, 'loss': 1.316849946975708}
# {'epoch': 2, 'batch': 60, 'loss': 1.355806827545166}
# {'epoch': 2, 'batch': 90, 'loss': 1.2991418838500977}
# {'epoch': 2, 'batch': 120, 'loss': 1.3237789869308472}
# {'epoch': 2, 'batch': 150, 'loss': 1.3009315729141235}
# {'epoch': 3, 'batch': 0, 'loss': 1.2232778072357178}
# {'epoch': 3, 'batch': 30, 'loss': 1.2750624418258667}
# {'epoch': 3, 'batch': 60, 'loss': 1.2809503078460693}
# {'epoch': 3, 'batch': 90, 'loss': 1.2493976354599}
# {'epoch': 3, 'batch': 120, 'loss': 1.2648500204086304}
# {'epoch': 3, 'batch': 150, 'loss': 1.294031023979187}
# {'epoch': 4, 'batch': 0, 'loss': 1.192518949508667}
# {'epoch': 4, 'batch': 30, 'loss': 1.2135823965072632}
# {'epoch': 4, 'batch': 60, 'loss': 1.2172225713729858}
# {'epoch': 4, 'batch': 90, 'loss': 1.2265316247940063}
# {'epoch': 4, 'batch': 120, 'loss': 1.2508935928344727}
# {'epoch': 4, 'batch': 150, 'loss': 1.1933056116104126}
# {'epoch': 5, 'batch': 0, 'loss': 1.1477088928222656}
# {'epoch': 5, 'batch': 30, 'loss': 1.1287894248962402}
# {'epoch': 5, 'batch': 60, 'loss': 1.1696959733963013}
# {'epoch': 5, 'batch': 90, 'loss': 1.1366163492202759}
# {'epoch': 5, 'batch': 120, 'loss': 1.1420977115631104}
# {'epoch': 5, 'batch': 150, 'loss': 1.2159194946289062}
# {'epoch': 6, 'batch': 0, 'loss': 1.088810920715332}
# {'epoch': 6, 'batch': 30, 'loss': 1.1071512699127197}
# {'epoch': 6, 'batch': 60, 'loss': 1.0956859588623047}
# {'epoch': 6, 'batch': 90, 'loss': 1.0795234441757202}
# {'epoch': 6, 'batch': 120, 'loss': 1.103617548942566}
# {'epoch': 6, 'batch': 150, 'loss': 1.1192734241485596}
# {'epoch': 7, 'batch': 0, 'loss': 1.0121971368789673}
# {'epoch': 7, 'batch': 30, 'loss': 1.008234977722168}
# {'epoch': 7, 'batch': 60, 'loss': 1.0295608043670654}
# {'epoch': 7, 'batch': 90, 'loss': 1.0542840957641602}
# {'epoch': 7, 'batch': 120, 'loss': 1.060442328453064}
# {'epoch': 7, 'batch': 150, 'loss': 1.073731541633606}
# {'epoch': 8, 'batch': 0, 'loss': 0.9488149285316467}
# {'epoch': 8, 'batch': 30, 'loss': 0.9550539255142212}
# {'epoch': 8, 'batch': 60, 'loss': 0.9604527354240417}
# {'epoch': 8, 'batch': 90, 'loss': 0.979145884513855}
# {'epoch': 8, 'batch': 120, 'loss': 0.9877883195877075}
# {'epoch': 8, 'batch': 150, 'loss': 0.993755042552948}
# {'epoch': 9, 'batch': 0, 'loss': 0.8986077904701233}
# {'epoch': 9, 'batch': 30, 'loss': 0.8929650783538818}
# {'epoch': 9, 'batch': 60, 'loss': 0.8743243217468262}
# {'epoch': 9, 'batch': 90, 'loss': 0.89886474609375}
# {'epoch': 9, 'batch': 120, 'loss': 0.9247260093688965}
# {'epoch': 9, 'batch': 150, 'loss': 0.945946455001831}
# {'epoch': 10, 'batch': 0, 'loss': 0.8365695476531982}
# {'epoch': 10, 'batch': 30, 'loss': 0.8082831501960754}
# {'epoch': 10, 'batch': 60, 'loss': 0.8457344770431519}
# {'epoch': 10, 'batch': 90, 'loss': 0.8778544068336487}
# {'epoch': 10, 'batch': 120, 'loss': 0.8500069975852966}
# {'epoch': 10, 'batch': 150, 'loss': 0.8796725273132324}
# {'epoch': 11, 'batch': 0, 'loss': 0.7554787397384644}
# {'epoch': 11, 'batch': 30, 'loss': 0.7231103777885437}
# {'epoch': 11, 'batch': 60, 'loss': 0.7570488452911377}
# {'epoch': 11, 'batch': 90, 'loss': 0.7794038653373718}
# {'epoch': 11, 'batch': 120, 'loss': 0.7780957818031311}
# {'epoch': 11, 'batch': 150, 'loss': 0.7965618968009949}
# {'epoch': 12, 'batch': 0, 'loss': 0.6668760180473328}
# {'epoch': 12, 'batch': 30, 'loss': 0.660076379776001}
# {'epoch': 12, 'batch': 60, 'loss': 0.6795016527175903}
# {'epoch': 12, 'batch': 90, 'loss': 0.6848399639129639}
# {'epoch': 12, 'batch': 120, 'loss': 0.7235634326934814}
# {'epoch': 12, 'batch': 150, 'loss': 0.7309807538986206}
# {'epoch': 13, 'batch': 0, 'loss': 0.5698071122169495}
# {'epoch': 13, 'batch': 30, 'loss': 0.5752422213554382}
# {'epoch': 13, 'batch': 60, 'loss': 0.6020160913467407}
# {'epoch': 13, 'batch': 90, 'loss': 0.6215600371360779}
# {'epoch': 13, 'batch': 120, 'loss': 0.6487944722175598}
# {'epoch': 13, 'batch': 150, 'loss': 0.6647371649742126}
# {'epoch': 14, 'batch': 0, 'loss': 0.5074918270111084}
# {'epoch': 14, 'batch': 30, 'loss': 0.5162148475646973}
# {'epoch': 14, 'batch': 60, 'loss': 0.5250925421714783}
# {'epoch': 14, 'batch': 90, 'loss': 0.544610321521759}
# {'epoch': 14, 'batch': 120, 'loss': 0.5707386136054993}
# {'epoch': 14, 'batch': 150, 'loss': 0.5872416496276855}
# {'epoch': 15, 'batch': 0, 'loss': 0.4298359751701355}
# {'epoch': 15, 'batch': 30, 'loss': 0.4207589328289032}
# {'epoch': 15, 'batch': 60, 'loss': 0.4454253017902374}
# {'epoch': 15, 'batch': 90, 'loss': 0.46294891834259033}
# {'epoch': 15, 'batch': 120, 'loss': 0.492075115442276}
# {'epoch': 15, 'batch': 150, 'loss': 0.521538257598877}
# {'epoch': 16, 'batch': 0, 'loss': 0.38709086179733276}
# {'epoch': 16, 'batch': 30, 'loss': 0.37261736392974854}
# {'epoch': 16, 'batch': 60, 'loss': 0.3861752450466156}
# {'epoch': 16, 'batch': 90, 'loss': 0.40690749883651733}
# {'epoch': 16, 'batch': 120, 'loss': 0.4130273759365082}
# {'epoch': 16, 'batch': 150, 'loss': 0.4534452557563782}
# {'epoch': 17, 'batch': 0, 'loss': 0.32222819328308105}
# {'epoch': 17, 'batch': 30, 'loss': 0.3296881914138794}
# {'epoch': 17, 'batch': 60, 'loss': 0.32286757230758667}
# {'epoch': 17, 'batch': 90, 'loss': 0.35835617780685425}
# {'epoch': 17, 'batch': 120, 'loss': 0.3666329085826874}
# {'epoch': 17, 'batch': 150, 'loss': 0.3917742669582367}
# {'epoch': 18, 'batch': 0, 'loss': 0.2932681739330292}
# {'epoch': 18, 'batch': 30, 'loss': 0.27710700035095215}
# {'epoch': 18, 'batch': 60, 'loss': 0.29341939091682434}
# {'epoch': 18, 'batch': 90, 'loss': 0.2989393174648285}
# {'epoch': 18, 'batch': 120, 'loss': 0.3253469169139862}
# {'epoch': 18, 'batch': 150, 'loss': 0.34339889883995056}
# {'epoch': 19, 'batch': 0, 'loss': 0.2616637349128723}
# {'epoch': 19, 'batch': 30, 'loss': 0.2551429271697998}
# {'epoch': 19, 'batch': 60, 'loss': 0.23526647686958313}
# {'epoch': 19, 'batch': 90, 'loss': 0.2714638113975525}
# {'epoch': 19, 'batch': 120, 'loss': 0.27112480998039246}
# {'epoch': 19, 'batch': 150, 'loss': 0.29656344652175903}
# {'epoch': 20, 'batch': 0, 'loss': 0.21612900495529175}
# {'epoch': 20, 'batch': 30, 'loss': 0.22607038915157318}
# {'epoch': 20, 'batch': 60, 'loss': 0.2159256935119629}
# {'epoch': 20, 'batch': 90, 'loss': 0.23526424169540405}
# {'epoch': 20, 'batch': 120, 'loss': 0.25788721442222595}
# {'epoch': 20, 'batch': 150, 'loss': 0.26055362820625305}
# {'epoch': 21, 'batch': 0, 'loss': 0.1957138478755951}
# {'epoch': 21, 'batch': 30, 'loss': 0.20514051616191864}
# {'epoch': 21, 'batch': 60, 'loss': 0.20819486677646637}
# {'epoch': 21, 'batch': 90, 'loss': 0.21251168847084045}
# {'epoch': 21, 'batch': 120, 'loss': 0.2243889570236206}
# {'epoch': 21, 'batch': 150, 'loss': 0.24593327939510345}
# {'epoch': 22, 'batch': 0, 'loss': 0.17512758076190948}
# {'epoch': 22, 'batch': 30, 'loss': 0.18954889476299286}
# {'epoch': 22, 'batch': 60, 'loss': 0.1948809027671814}
# {'epoch': 22, 'batch': 90, 'loss': 0.20631803572177887}
# {'epoch': 22, 'batch': 120, 'loss': 0.21404050290584564}
# {'epoch': 22, 'batch': 150, 'loss': 0.2237134873867035}
# {'epoch': 23, 'batch': 0, 'loss': 0.17559097707271576}
# {'epoch': 23, 'batch': 30, 'loss': 0.1763666868209839}
# {'epoch': 23, 'batch': 60, 'loss': 0.1862863302230835}
# {'epoch': 23, 'batch': 90, 'loss': 0.19118675589561462}
# {'epoch': 23, 'batch': 120, 'loss': 0.2104877531528473}
# {'epoch': 23, 'batch': 150, 'loss': 0.22786392271518707}
# {'epoch': 24, 'batch': 0, 'loss': 0.15816254913806915}
# {'epoch': 24, 'batch': 30, 'loss': 0.16984225809574127}
# {'epoch': 24, 'batch': 60, 'loss': 0.18402834236621857}
# {'epoch': 24, 'batch': 90, 'loss': 0.19273178279399872}
# {'epoch': 24, 'batch': 120, 'loss': 0.2074177861213684}
# {'epoch': 24, 'batch': 150, 'loss': 0.21579797565937042}
# {'epoch': 25, 'batch': 0, 'loss': 0.16273969411849976}
# {'epoch': 25, 'batch': 30, 'loss': 0.17297524213790894}
# {'epoch': 25, 'batch': 60, 'loss': 0.1826293170452118}
# {'epoch': 25, 'batch': 90, 'loss': 0.1985192447900772}
# {'epoch': 25, 'batch': 120, 'loss': 0.2212572991847992}
# {'epoch': 25, 'batch': 150, 'loss': 0.23586611449718475}
# {'epoch': 26, 'batch': 0, 'loss': 0.18006059527397156}
# {'epoch': 26, 'batch': 30, 'loss': 0.18458177149295807}
# {'epoch': 26, 'batch': 60, 'loss': 0.1853831261396408}
# {'epoch': 26, 'batch': 90, 'loss': 0.20498952269554138}
# {'epoch': 26, 'batch': 120, 'loss': 0.20359455049037933}
# {'epoch': 26, 'batch': 150, 'loss': 0.23465842008590698}
# {'epoch': 27, 'batch': 0, 'loss': 0.15967592597007751}
# {'epoch': 27, 'batch': 30, 'loss': 0.18216055631637573}
# {'epoch': 27, 'batch': 60, 'loss': 0.18588708341121674}
# {'epoch': 27, 'batch': 90, 'loss': 0.1930045336484909}
# {'epoch': 27, 'batch': 120, 'loss': 0.20368774235248566}
# {'epoch': 27, 'batch': 150, 'loss': 0.21761980652809143}
# {'epoch': 28, 'batch': 0, 'loss': 0.17348751425743103}
# {'epoch': 28, 'batch': 30, 'loss': 0.17077785730361938}
# {'epoch': 28, 'batch': 60, 'loss': 0.17510005831718445}
# {'epoch': 28, 'batch': 90, 'loss': 0.18601998686790466}
# {'epoch': 28, 'batch': 120, 'loss': 0.19675831496715546}
# {'epoch': 28, 'batch': 150, 'loss': 0.20870943367481232}
# {'epoch': 29, 'batch': 0, 'loss': 0.16234515607357025}
# {'epoch': 29, 'batch': 30, 'loss': 0.16493791341781616}
# {'epoch': 29, 'batch': 60, 'loss': 0.16654802858829498}
# {'epoch': 29, 'batch': 90, 'loss': 0.17511020600795746}
# {'epoch': 29, 'batch': 120, 'loss': 0.18532411754131317}
# {'epoch': 29, 'batch': 150, 'loss': 0.20487023890018463}

# %%
losses_models = {'GRU' : losses_gru, 'RNN' : losses_rnn, 'LSTM' : lossesLSTM}

# %%
# Plotting losses
plt.figure()
for loss in losses_models.keys():
    plt.plot(losses_models[loss], label=loss)
plt.xlabel("Iterations")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# <span style="color:blue">
#
# **Exercise 4:** Train your best model on a different dataset. Use the 'inaugural' corpus of the [NLTK](https://www.nltk.org/) library. Once trained generate some text with as we did for the model trained on the Shakespeare dataset. Compare the generated texts with both models using the smae "seed" (input) text. What differences do you appreciate? Why are they different?
#
# </span>
#
# The Natural Language Toolkit, or more commonly NLTK, is a suite of datasets, libraries and models for symbolic and statistical natural language processing (NLP). The Inaugural Address Corpus contains the US presidential inaugural addresses from 1789 to 2017. The following code loads the 'inaugural' corpus:

# %%
class DatasetFromRawText(): # Just no the file version done for inaugural
    def __init__(self, text, sequence_length):
        self.sequence_length = sequence_length
        # The whole sequence of characters in the text file (including characters like the end of line character '\n', punctuation marks, etc.)
        self.chars = text
        print(f'Length of text: {len(text)} characters')

        # The list of unique characters (our vocabulary)
        self.uniq_chars = self.get_uniq_chars()

        # A dictionary with indices as keys and characters as values
        self.index_to_char = {index: char for index, char in enumerate(self.uniq_chars)}
        # A dictionary with characters as keys and indices as values
        self.char_to_index = {char: index for index, char in enumerate(self.uniq_chars)}

        # The whole sequence of character indexes
        # We want to vectorize our text using one-hot vectors at character level
        # But instead of using the one-hot vector we just keep the index of the 1 value
        self.chars_indices = [self.char_to_index[w] for w in self.chars]

        # Split the sequence into chunks of `sequence_length` characters
        # `x` is the input to the model and `y` is the output of the model
        # `y` is the same seuqence as `x` but one character shifted to the right.
        self.x, self.y = self.get_data()

    def get_uniq_chars(self):
        char_counts = Counter(self.chars)
        uniq_chars = sorted(char_counts, key=char_counts.get, reverse=True)
        print(f'Unique characters (vocabulary size): {len(uniq_chars)}')
        return uniq_chars

    def get_data(self):
        x,y = [], []
        for index in range(0, len(self.chars_indices)-self.sequence_length, self.sequence_length):
            x.append(np.array(self.chars_indices[index:index+self.sequence_length]))
            y.append(np.array(self.chars_indices[index+1:index+self.sequence_length+1]))

        return  torch.from_numpy(np.array(x)), torch.from_numpy(np.array(y)).long()

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
          assert ((idx >= 0) & (idx < len(self.y))), "Dataset index out of range"
          return self.x[idx], self.y[idx]

# %%
import nltk

nltk.download('inaugural')
inaugural = nltk.corpus.inaugural
text = inaugural.raw()

print(f'Length of text: {len(text)} characters')

sequence_length = 100
InauguralDataset = DatasetFromRawText(inaugural.raw(), sequence_length)

print(f'We have {InauguralDataset.x.shape[0]} input sequence samples of length {InauguralDataset.x.shape[1]} \
and {InauguralDataset.y.shape[0]} label sequences of length {InauguralDataset.y.shape[1]}')


batch_size = 64
train_loader_inaugural = DataLoader(InauguralDataset, shuffle=True, batch_size=batch_size, drop_last=True)
# Out:
# [nltk_data] Downloading package inaugural to /root/nltk_data...
# [nltk_data]   Package inaugural is already up-to-date!
# Length of text: 807276 characters
# Length of text: 807276 characters
# Unique characters (vocabulary size): 85
# We have 8072 input sequence samples of length 100 and 8072 label sequences of length 100

# %%
# Train the model
input_dim = len(InauguralDataset.uniq_chars)
embedding_dim = 300
hidden_dim = 1024
output_dim = len(InauguralDataset.uniq_chars)
n_layers = 2
drop_prob = 0.2

model_LSTMN_inaugural = model_LSTM(input_dim, embedding_dim, hidden_dim, output_dim, n_layers, drop_prob).to(device)
losses_inaugural = train_LSTM(train_loader_inaugural, model_LSTMN_inaugural, batch_size, sequence_length, num_epochs=30)
# Out:
# {'epoch': 0, 'batch': 0, 'loss': 4.443977355957031}
# {'epoch': 0, 'batch': 30, 'loss': 2.314138889312744}
# {'epoch': 0, 'batch': 60, 'loss': 1.913730502128601}
# {'epoch': 0, 'batch': 90, 'loss': 1.6514085531234741}
# {'epoch': 0, 'batch': 120, 'loss': 1.5158025026321411}
# {'epoch': 1, 'batch': 0, 'loss': 1.4622691869735718}
# {'epoch': 1, 'batch': 30, 'loss': 1.407466173171997}
# {'epoch': 1, 'batch': 60, 'loss': 1.3432648181915283}
# {'epoch': 1, 'batch': 90, 'loss': 1.2671278715133667}
# {'epoch': 1, 'batch': 120, 'loss': 1.2726924419403076}
# {'epoch': 2, 'batch': 0, 'loss': 1.2403384447097778}
# {'epoch': 2, 'batch': 30, 'loss': 1.2159037590026855}
# {'epoch': 2, 'batch': 60, 'loss': 1.16117525100708}
# {'epoch': 2, 'batch': 90, 'loss': 1.183569312095642}
# {'epoch': 2, 'batch': 120, 'loss': 1.1969068050384521}
# {'epoch': 3, 'batch': 0, 'loss': 1.1490445137023926}
# {'epoch': 3, 'batch': 30, 'loss': 1.1459574699401855}
# {'epoch': 3, 'batch': 60, 'loss': 1.1205401420593262}
# {'epoch': 3, 'batch': 90, 'loss': 1.1253021955490112}
# {'epoch': 3, 'batch': 120, 'loss': 1.1436612606048584}
# {'epoch': 4, 'batch': 0, 'loss': 1.1056808233261108}
# {'epoch': 4, 'batch': 30, 'loss': 1.0601108074188232}
# {'epoch': 4, 'batch': 60, 'loss': 1.098542332649231}
# {'epoch': 4, 'batch': 90, 'loss': 1.0735790729522705}
# {'epoch': 4, 'batch': 120, 'loss': 1.0834856033325195}
# {'epoch': 5, 'batch': 0, 'loss': 1.0387202501296997}
# {'epoch': 5, 'batch': 30, 'loss': 1.039487361907959}
# {'epoch': 5, 'batch': 60, 'loss': 1.0504693984985352}
# {'epoch': 5, 'batch': 90, 'loss': 1.074175238609314}
# {'epoch': 5, 'batch': 120, 'loss': 1.0709278583526611}
# {'epoch': 6, 'batch': 0, 'loss': 0.9879451990127563}
# {'epoch': 6, 'batch': 30, 'loss': 1.017566204071045}
# {'epoch': 6, 'batch': 60, 'loss': 1.0047519207000732}
# {'epoch': 6, 'batch': 90, 'loss': 1.0180044174194336}
# {'epoch': 6, 'batch': 120, 'loss': 1.0407161712646484}
# {'epoch': 7, 'batch': 0, 'loss': 0.9420410394668579}
# {'epoch': 7, 'batch': 30, 'loss': 0.9950172901153564}
# {'epoch': 7, 'batch': 60, 'loss': 0.9783338308334351}
# {'epoch': 7, 'batch': 90, 'loss': 0.9849435687065125}
# {'epoch': 7, 'batch': 120, 'loss': 0.9850106239318848}
# {'epoch': 8, 'batch': 0, 'loss': 0.9364317059516907}
# {'epoch': 8, 'batch': 30, 'loss': 0.9475836753845215}
# {'epoch': 8, 'batch': 60, 'loss': 0.9444659352302551}
# {'epoch': 8, 'batch': 90, 'loss': 0.9383935332298279}
# {'epoch': 8, 'batch': 120, 'loss': 0.9764398336410522}
# {'epoch': 9, 'batch': 0, 'loss': 0.8846495151519775}
# {'epoch': 9, 'batch': 30, 'loss': 0.8830707669258118}
# {'epoch': 9, 'batch': 60, 'loss': 0.9131726026535034}
# {'epoch': 9, 'batch': 90, 'loss': 0.9020891785621643}
# {'epoch': 9, 'batch': 120, 'loss': 0.9299030900001526}
# {'epoch': 10, 'batch': 0, 'loss': 0.8733654022216797}
# {'epoch': 10, 'batch': 30, 'loss': 0.8565959334373474}
# {'epoch': 10, 'batch': 60, 'loss': 0.9007622599601746}
# {'epoch': 10, 'batch': 90, 'loss': 0.8803596496582031}
# {'epoch': 10, 'batch': 120, 'loss': 0.9158775210380554}
# {'epoch': 11, 'batch': 0, 'loss': 0.808795690536499}
# {'epoch': 11, 'batch': 30, 'loss': 0.8031848073005676}
# {'epoch': 11, 'batch': 60, 'loss': 0.833072304725647}
# {'epoch': 11, 'batch': 90, 'loss': 0.8337833285331726}
# {'epoch': 11, 'batch': 120, 'loss': 0.8446181416511536}
# {'epoch': 12, 'batch': 0, 'loss': 0.7764903903007507}
# {'epoch': 12, 'batch': 30, 'loss': 0.7672208547592163}
# {'epoch': 12, 'batch': 60, 'loss': 0.7581685781478882}
# {'epoch': 12, 'batch': 90, 'loss': 0.8095248341560364}
# {'epoch': 12, 'batch': 120, 'loss': 0.806529700756073}
# {'epoch': 13, 'batch': 0, 'loss': 0.7117146253585815}
# {'epoch': 13, 'batch': 30, 'loss': 0.7308589220046997}
# {'epoch': 13, 'batch': 60, 'loss': 0.7539288997650146}
# {'epoch': 13, 'batch': 90, 'loss': 0.7524685859680176}
# {'epoch': 13, 'batch': 120, 'loss': 0.768144428730011}
# {'epoch': 14, 'batch': 0, 'loss': 0.6706031560897827}
# {'epoch': 14, 'batch': 30, 'loss': 0.6603940725326538}
# {'epoch': 14, 'batch': 60, 'loss': 0.682919442653656}
# {'epoch': 14, 'batch': 90, 'loss': 0.7059825658798218}
# {'epoch': 14, 'batch': 120, 'loss': 0.7064892649650574}
# {'epoch': 15, 'batch': 0, 'loss': 0.6085878610610962}
# {'epoch': 15, 'batch': 30, 'loss': 0.6063418984413147}
# {'epoch': 15, 'batch': 60, 'loss': 0.6405726075172424}
# {'epoch': 15, 'batch': 90, 'loss': 0.6457895636558533}
# {'epoch': 15, 'batch': 120, 'loss': 0.6816138625144958}
# {'epoch': 16, 'batch': 0, 'loss': 0.5578429698944092}
# {'epoch': 16, 'batch': 30, 'loss': 0.5552063584327698}
# {'epoch': 16, 'batch': 60, 'loss': 0.5916290879249573}
# {'epoch': 16, 'batch': 90, 'loss': 0.5995119214057922}
# {'epoch': 16, 'batch': 120, 'loss': 0.6066799759864807}
# {'epoch': 17, 'batch': 0, 'loss': 0.5207577347755432}
# {'epoch': 17, 'batch': 30, 'loss': 0.5009399652481079}
# {'epoch': 17, 'batch': 60, 'loss': 0.5263475179672241}
# {'epoch': 17, 'batch': 90, 'loss': 0.5464081764221191}
# {'epoch': 17, 'batch': 120, 'loss': 0.5785968899726868}
# {'epoch': 18, 'batch': 0, 'loss': 0.4496181905269623}
# {'epoch': 18, 'batch': 30, 'loss': 0.449708491563797}
# {'epoch': 18, 'batch': 60, 'loss': 0.4655158221721649}
# {'epoch': 18, 'batch': 90, 'loss': 0.4917246103286743}
# {'epoch': 18, 'batch': 120, 'loss': 0.5054547786712646}
# {'epoch': 19, 'batch': 0, 'loss': 0.3997846245765686}
# {'epoch': 19, 'batch': 30, 'loss': 0.4103785455226898}
# {'epoch': 19, 'batch': 60, 'loss': 0.421514093875885}
# {'epoch': 19, 'batch': 90, 'loss': 0.44635632634162903}
# {'epoch': 19, 'batch': 120, 'loss': 0.454586386680603}
# {'epoch': 20, 'batch': 0, 'loss': 0.3677617609500885}
# {'epoch': 20, 'batch': 30, 'loss': 0.3674561679363251}
# {'epoch': 20, 'batch': 60, 'loss': 0.37371158599853516}
# {'epoch': 20, 'batch': 90, 'loss': 0.38975611329078674}
# {'epoch': 20, 'batch': 120, 'loss': 0.4276968240737915}
# {'epoch': 21, 'batch': 0, 'loss': 0.32325249910354614}
# {'epoch': 21, 'batch': 30, 'loss': 0.31699374318122864}
# {'epoch': 21, 'batch': 60, 'loss': 0.3248910903930664}
# {'epoch': 21, 'batch': 90, 'loss': 0.3455146849155426}
# {'epoch': 21, 'batch': 120, 'loss': 0.35227981209754944}
# {'epoch': 22, 'batch': 0, 'loss': 0.2680213451385498}
# {'epoch': 22, 'batch': 30, 'loss': 0.2799948751926422}
# {'epoch': 22, 'batch': 60, 'loss': 0.2825562655925751}
# {'epoch': 22, 'batch': 90, 'loss': 0.3141012489795685}
# {'epoch': 22, 'batch': 120, 'loss': 0.32975485920906067}
# {'epoch': 23, 'batch': 0, 'loss': 0.25334540009498596}
# {'epoch': 23, 'batch': 30, 'loss': 0.24483509361743927}
# {'epoch': 23, 'batch': 60, 'loss': 0.24401217699050903}
# {'epoch': 23, 'batch': 90, 'loss': 0.2701002061367035}
# {'epoch': 23, 'batch': 120, 'loss': 0.2865297794342041}
# {'epoch': 24, 'batch': 0, 'loss': 0.2166001945734024}
# {'epoch': 24, 'batch': 30, 'loss': 0.22039097547531128}
# {'epoch': 24, 'batch': 60, 'loss': 0.22587932646274567}
# {'epoch': 24, 'batch': 90, 'loss': 0.24300438165664673}
# {'epoch': 24, 'batch': 120, 'loss': 0.24975770711898804}
# {'epoch': 25, 'batch': 0, 'loss': 0.18664537370204926}
# {'epoch': 25, 'batch': 30, 'loss': 0.19125503301620483}
# {'epoch': 25, 'batch': 60, 'loss': 0.19555868208408356}
# {'epoch': 25, 'batch': 90, 'loss': 0.2044839859008789}
# {'epoch': 25, 'batch': 120, 'loss': 0.22192934155464172}
# {'epoch': 26, 'batch': 0, 'loss': 0.16788378357887268}
# {'epoch': 26, 'batch': 30, 'loss': 0.17245830595493317}
# {'epoch': 26, 'batch': 60, 'loss': 0.17508341372013092}
# {'epoch': 26, 'batch': 90, 'loss': 0.17859596014022827}
# {'epoch': 26, 'batch': 120, 'loss': 0.19111205637454987}
# {'epoch': 27, 'batch': 0, 'loss': 0.15420971810817719}
# {'epoch': 27, 'batch': 30, 'loss': 0.14067642390727997}
# {'epoch': 27, 'batch': 60, 'loss': 0.1746261715888977}
# {'epoch': 27, 'batch': 90, 'loss': 0.17135488986968994}
# {'epoch': 27, 'batch': 120, 'loss': 0.18200445175170898}
# {'epoch': 28, 'batch': 0, 'loss': 0.13650912046432495}
# {'epoch': 28, 'batch': 30, 'loss': 0.13870340585708618}
# {'epoch': 28, 'batch': 60, 'loss': 0.1496717780828476}
# {'epoch': 28, 'batch': 90, 'loss': 0.15325891971588135}
# {'epoch': 28, 'batch': 120, 'loss': 0.16466902196407318}
# {'epoch': 29, 'batch': 0, 'loss': 0.12555064260959625}
# {'epoch': 29, 'batch': 30, 'loss': 0.13528171181678772}
# {'epoch': 29, 'batch': 60, 'loss': 0.14192909002304077}
# {'epoch': 29, 'batch': 90, 'loss': 0.14436359703540802}
# {'epoch': 29, 'batch': 120, 'loss': 0.1583888977766037}

# %%
# Visualize the loss evolution during training
plt.plot(losses_inaugural)
plt.title('Model loss')
plt.show()

# %%
def predictMOD(model, text, dataset, device, next_chars):
    model.eval()

    chars = [char for char in text]
    h = model.init_hidden(1)  # Initialize hidden state
    h = tuple(s.to(device) for s in h)  # Move hidden state to device

    for i in range(next_chars):
        x = torch.tensor([[dataset.char_to_index[char] for char in chars[i:]]]).to(device)
        y_pred, h = model(x, h)

        last_char_logits = y_pred[0][-1]
        p = torch.nn.functional.softmax(last_char_logits, dim=0).detach().cpu().numpy()
        char_index = np.random.choice(len(last_char_logits), p=p)
        chars.append(dataset.index_to_char[char_index])

    return ''.join(chars)



print ('------------Shakespeare---------------')
predicted = predictMOD(model=model_lstm_simple, text='What can', dataset=ShakespeareDataset, device=device, next_chars=2000)
print(''.join(predicted))
print('\n\n-------------------------------------------------------------------------------------------')
print ('------------Inaugural---------------')
predicted = predictMOD(model=model_LSTMN_inaugural, text='What can', dataset=InauguralDataset, device=device, next_chars=2000)
print(predicted)
# Out:
# ------------Shakespeare---------------
# What can a royal
# A prince and old,
# While had in,
# too in the rest
# Shall, in slave;
# For this I play
# With 'Thanishes,
# The obide,
# though they would
# The frowns.
#
# MESCUS:
# Why, brother,
# If e'er and sworn.
# 'Tis inquired
# With five thou
# breeding thou
# and the people
# To what hash
# Gills and us;
# For this unloved
# than stoops of war.
#
# First Senator:
# You shall know to-night:
# we'll upon him.
#
# First Citizen:
# Well, we'll deal:
# And for a soldier, and
# Cry our strive
# A trod defend;
# But she's hown he
# shall be up,
# gait and shrends
# I never be a
# man: 'tis now.
#
# CAPULET:
# What is bond?
# O, good sweetly,
# Since, let their prince,
# Even to those thine.
#
# CURTIS:
# What, would I,
# Verona, it more
# Than two would,
# Thou came to you
# Of what will inform'd in breasts:
# if thou been,
# Audier way here,
# After times
# With joy. Therefore,
# And occupation;
# For theirs as,
# And once again, and such
# fives and straight:
# For winter special,
# and out their
# to all in kiss,
# A proper talk
# Juliet in the
# bost; bloody, take
# The treason:
# Away! there straws,
# All so valiant.
#
# KING HENRY VI:
# But die, believed.
# Fie, what of him,
# had I move,
# You must away.
# 3 KING HENRY VI:
# Camillo it you
# Where are you
# not what old
# Whom when he
# contented that
# Which I cannot be;
# A falcon'd with for
# estimage all;
# And doth lengthen,
# My fortune till
# We make trees to
# warning in storms.
# But with Aufolecy,
# But one, a feast,
# Were take off
# when Bolingbroke,
# It doth lament,
# And in the better them,
# But my discontent:
# 'Tis, my Kate;
# And, if angen,
# So in the bond
# That God, with him,
# More than so:
# Thou didst thou
# for this wonts.
# I prisoner.
# Here sixteen,
# Could not behind;
# but those pronounced us wont,
# Alack that blows,
# She should be drunkard
# By winged Clarence down
# Doth longing,
# As you are,
# Most joyberday.
# Doth hath been
# sequently: my
# sheep ware upon him.
#
# First Citizen:
# Well, well met
# As the more
# Than to any,
# out to arise,
# And may not,
# But themselves
# We thrusts to the world,
# The trick o' the ear;
# While I left at the
# Geen ballady,
# Ere three paid,
# all in whiles
# In half a thought,
#
#
# -------------------------------------------------------------------------------------------
# ------------Inaugural---------------
# What can be hearded are virtue and have make the pledged in a state to my appoints to one question to adjust in the Congress not like theory of a hard to his judgment against distance in him who are those who violence the cherished hitherto prevailed, now decisive attainment stricted by the created. If the plosed to you on the Washington New "YOS TENENTOR OF THE ENGONCENTETENON THE GONERNATION
# This is deeply crvitments -- the knowledge and officers.
#
# One sections one varied rights as the homes of the countries. To the SatiF¡I had continues for the Governments and the hope to widening you, knowing the time, is the rights as the desire to the most the men that centuries, and safety, and fighting in the arts toward here today. They acted as a saint of those whole had a pain of us has to been abuses insulting at home to what is the highly defining and vigor. We are told of the majority president to such an abiding counterance one party in the President Americans urged Bepositing to my fellow citizens large and make theme to himself a city -- to the States is a supromation and over them within the developmen, will sacrifice and leave no less voters drawn to the decisel. In the history depend, and yet cease to her serviced upon the paramount of those States in the articles over the responsibility. These are much you has given there will hearts and success. They are from the God halfly behind the highly by the organization and admiring that certainly they time require for the high officers an interestlying those threatens in the authorized imposes to defray the most cheerful shall stand for her fith sufficient during the utmost ever drop. No the understates the principles on my purposes, and so, at the positils, canable but to secure the most ardents, victory after had necessary to the others, it is the will be ablo for its moral drawn by what is entitled to my best for the problems by the legislation from the responsing all to us for yours. It is Americans, 2 Your DEENCILI
# In the

# %% [markdown]
# Evidently, the content, organization and manners are completly different. This is simply beacuse they were trained with bastly different data, so each model learned to imitate the data they were fed.
